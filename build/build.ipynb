# %%
import os,json
import markdown as md
import codecs

# %% [markdown]
# # Build lesson

# %%
def makehtml(path,nav=0,level=0,lessontype="terminal"):
    
    templatefilepath='./template/{templatefilename}.html'
    templatefilepath=templatefilepath.replace('{templatefilename}',lessontype)
    htmltemplatefile=open(templatefilepath,'r',encoding="utf-8")
    htmltemplate=htmltemplatefile.read()
    htmltemplatefile.close()


    if level!=0:
        leftnavcontent=nav
    else:
        navfilefile=open(os.path.join(path,"nav.html"), mode="r", encoding="utf-8")
        leftnavcontent=navfilefile.read()
        navfilefile.close()
    
    
    topheadertemplate=open('./template/topheader.html','r',encoding="utf-8")
    topheader=topheadertemplate.read()
    
    for root,dirs,files in os.walk(path):
        for name in files:
            abs_path=os.path.join(root,name)
            print(abs_path)
            (filename,extension)=os.path.splitext(name)
            print("filename",filename,"   extension",extension)
            
            if extension==".md":
                md_file = codecs.open(abs_path, mode="r", encoding="utf-8")
                md_htmlcontent = md.markdown(md_file.read(),extensions=['fenced_code','tables'])
                md_file.close()
                

                html_filename=os.path.join(os.path.dirname(abs_path),filename+".html")
                print(html_filename)
                html_file = codecs.open(html_filename, mode="w", encoding="utf-8")
                
                
                template=htmltemplate
                title=md_htmlcontent.split('\n')[0]
                title=title.replace('<h1>','')
                title=title.replace('</h1>','')
                title=title+" - FreeAIHub"
                template=template.replace('{title}',title)
                template=template.replace('{leftnav}', leftnavcontent)
                template=template.replace('{content}',md_htmlcontent)
                template=template.replace('{topheader}',topheader)
                html_file.write(template)
                html_file.close()
                
        for name in dirs:
            makehtml(os.path.join(root,name),nav=leftnavcontent,level=1)

# %%
news=['aboutus']
terminal=['java','pyqt','turtle','php','jmeter','html','elasticsearch','hive','hbase','redis','scala','c','spark','sqlite','tornado',\
         'vim','go','git','flask','cpp','django','postgresql','ds-in-c','neo4j','ds-in-python','lua','hadoop','mysql','mongodb','nginx','shell',\
         'nodejs','linux','jupyter']
cell_python=['d2l-mxnet','d2l-pyroch','pandas','numpy','keras','ml','seaborn','scipy','sklearn','python']
cell_ir=['r']
cell_julia=['julia']
vm=['docker']

# %%
# for item in news:
#     makehtml('../'+item,lessontype="news")
    
for item in terminal:
    makehtml('../'+item,lessontype="terminal")
    
# for item in cell_python:
#     makehtml('../'+item,lessontype="cell_python")

# for item in cell_ir:
#     makehtml('../'+item,lessontype="cell_ir")

# for item in cell_julia:
#     makehtml('../'+item,lessontype="cell_julia")
    
    
# for item in vm:
#     makehtml('../'+item,lessontype="vm")
# Out:
# ../java\access-modifiers.html
# filename access-modifiers    extension .html
# ../java\access-modifiers.md
# filename access-modifiers    extension .md
# ../java\access-modifiers.html
# ../java\array.html
# filename array    extension .html
# ../java\array.md
# filename array    extension .md
# ../java\array.html
# ../java\break.html
# filename break    extension .html
# ../java\break.md
# filename break    extension .md
# ../java\break.html
# ../java\character.html
# filename character    extension .html
# ../java\character.md
# filename character    extension .md
# ../java\character.html
# ../java\continue.html
# filename continue    extension .html
# ../java\continue.md
# filename continue    extension .md
# ../java\continue.html
# ../java\datatype.html
# filename datatype    extension .html
# ../java\datatype.md
# filename datatype    extension .md
# ../java\datatype.html
# ../java\datetime.html
# filename datetime    extension .html
# ../java\datetime.md
# filename datetime    extension .md
# ../java\datetime.html
# ../java\do-while.html
# filename do-while    extension .html
# ../java\do-while.md
# filename do-while    extension .md
# ../java\do-while.html
# ../java\exceptions.html
# filename exceptions    extension .html
# ../java\exceptions.md
# filename exceptions    extension .md
# ../java\exceptions.html
# ../java\for.html
# filename for    extension .html
# ../java\for.md
# filename for    extension .md
# ../java\for.html
# ../java\if-else.html
# filename if-else    extension .html
# ../java\if-else.md
# filename if-else    extension .md
# ../java\if-else.html
# ../java\if-nested.html
# filename if-nested    extension .html
# ../java\if-nested.md
# filename if-nested    extension .md
# ../java\if-nested.html
# ../java\if.html
# filename if    extension .html
# ../java\if.md
# filename if    extension .md
# ../java\if.html
# ../java\index.html
# filename index    extension .html
# ../java\index.md
# filename index    extension .md
# ../java\index.html
# ../java\intro.html
# filename intro    extension .html
# ../java\intro.md
# filename intro    extension .md
# ../java\intro.html
# ../java\io.html
# filename io    extension .html
# ../java\io.md
# filename io    extension .md
# ../java\io.html
# ../java\logic.html
# filename logic    extension .html
# ../java\logic.md
# filename logic    extension .md
# ../java\logic.html
# ../java\loop.html
# filename loop    extension .html
# ../java\loop.md
# filename loop    extension .md
# ../java\loop.html
# ../java\method.html
# filename method    extension .html
# ../java\method.md
# filename method    extension .md
# ../java\method.html
# ../java\modifier.html
# filename modifier    extension .html
# ../java\modifier.md
# filename modifier    extension .md
# ../java\modifier.html
# ../java\nav.html
# filename nav    extension .html
# ../java\nonaccess-modifiers.html
# filename nonaccess-modifiers    extension .html
# ../java\nonaccess-modifiers.md
# filename nonaccess-modifiers    extension .md
# ../java\nonaccess-modifiers.html
# ../java\number.html
# filename number    extension .html
# ../java\number.md
# filename number    extension .md
# ../java\number.html
# ../java\object-class.html
# filename object-class    extension .html
# ../java\object-class.md
# filename object-class    extension .md
# ../java\object-class.html
# ../java\operator.html
# filename operator    extension .html
# ../java\operator.md
# filename operator    extension .md
# ../java\operator.html

# %% [markdown]
# # build index

# %%
indexjson=json.loads(open('./template/index.json',encoding='utf-8').read())

# %%
lessontypehtmltemplate='''
            <div class="row clearfix">
                <div class="index-title"><h4>{name}</h4></div>
                <!--Service Style Three-->
'''
lessontypehtmltemplateend='''
            </div>
'''

lessonhtmltemplate='''
                    <div class="service-style-three col-md-4 col-sm-6 col-xs-12">
                        <div class="inner-box">
                            <div class="icon"><figure class="image"><img src="{img}" alt="{name}"></figure></div>
                            <h3><a href="{link}">{name}</a></h3>
                            <div class="text">{des}</div>
                        </div>
                    </div>
'''

# %%
final=''
courses=indexjson['Course']['CourseList']
for coursetype in courses:
    final+=lessontypehtmltemplate.replace('{name}',courses[coursetype]['name'])
    for item in courses[coursetype]['lessons']:
#         print(item)
        temp=lessonhtmltemplate.replace('{link}',item['link'])
        temp=temp.replace('{name}',item['name'])
        temp=temp.replace('{des}',item['des'])
        temp=temp.replace('{img}',item['img'])
        final+=temp
        temp=''
    final+=lessontypehtmltemplateend

# %%
index_file = codecs.open("../index.html", mode="w", encoding="utf-8")
index_template = codecs.open("./template/index.template", mode="r", encoding="utf-8").read()

index_template=index_template.replace('{lessonlists}',final)
index_file.write(index_template)
